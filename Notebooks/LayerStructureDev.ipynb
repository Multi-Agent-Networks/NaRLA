# %% [markdown]
# # MAN
# * Layer and Multi Agent Network Encapsulation

# %%
import sys
import time
sys.path.append('..')

import tensorflow as tf
import matplotlib.pyplot as plt
from narla.man import MultiAgentNetwork

# %load_ext tensorboard

# %%
x = tf.random.uniform((1, 3))
man = MultiAgentNetwork(input_size=3, num_layers=3)
_=man(x)

# %% [markdown]
# ### Trace Graph
# * To trace the graph comment out the @tf.function decorators in layer.py and node.py

# %%
# !rm -rf logs
# !mkdir logs

# %%
logdir = 'logs/man_setup/' 
writer = tf.summary.create_file_writer(logdir)

tf.summary.trace_on(graph=True, profiler=False)

man.compute(x)

with writer.as_default():
    tf.summary.trace_export(
        name="man_trace",
        step=0,
        profiler_outdir=logdir
    )

# %%
# %tensorboard --logdir logs/man_setup
# Out:
# Reusing TensorBoard on port 6010 (pid 115060), started 6 days, 3:55:03 ago. (Use '!kill 115060' to kill it.)
#       <iframe id="tensorboard-frame-8f88447294cbd9e9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8f88447294cbd9e9");
#           const url = new URL("/", window.location);
#           const port = 6010;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
