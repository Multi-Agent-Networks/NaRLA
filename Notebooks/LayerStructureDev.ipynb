# %% [markdown]
# # MAN
# * Layer and Multi Agent Network Encapsulation

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from narla.man import MultiAgentNetwork

# %load_ext tensorboard

# %%
x = tf.random.uniform((1, 3))
man = MultiAgentNetwork(input_size=3, num_layers=3)
_=man(x)

# %% [markdown]
# ### Trace Graph
# * To trace the graph comment out the @tf.function decorators in layer.py and node.py

# %%
# !rm -rf logs
# !mkdir logs

# %%
logdir = 'logs/man_setup/' 
writer = tf.summary.create_file_writer(logdir)

tf.summary.trace_on(graph=True, profiler=False)

man(x)

with writer.as_default():
    tf.summary.trace_export(
        name="man_trace",
        step=0,
        profiler_outdir=logdir
    )
# Out:
# WARNING:tensorflow:Trace already enabled
# WARNING:tensorflow:From /home/jordan/env/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.

# %%
# %tensorboard --logdir logs/man_setup
# Out:
#       <iframe id="tensorboard-frame-3b40ba9085c13c3e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3b40ba9085c13c3e");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
